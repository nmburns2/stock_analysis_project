# %%
import pandas as pd
import numpy as np
import finnhub
finnhub_client = finnhub.Client(api_key="btv5pnf48v6q7nvmtllg")

# %%
tsla_est = finnhub_client.company_revenue_estimates('TSLA', freq='annual')
tsla_df = pd.DataFrame(tsla_est)
tsla_est
# Out:
# {'data': [{'numberAnalysts': 21,
#    'period': '2024-12-31',
#    'revenueAvg': 96416624918,
#    'revenueHigh': 100273289915,
#    'revenueLow': 93524126171},
#   {'numberAnalysts': 21,
#    'period': '2023-12-31',
#    'revenueAvg': 71828831980,
#    'revenueHigh': 74701985259,
#    'revenueLow': 69673967020},
#   {'numberAnalysts': 25,
#    'period': '2022-12-31',
#    'revenueAvg': 54313992266,
#    'revenueHigh': 70521882000,
#    'revenueLow': 35304120000},
#   {'numberAnalysts': 31,
#    'period': '2021-12-31',
#    'revenueAvg': 41937343852,
#    'revenueHigh': 50703180000,
#    'revenueLow': 31743250000},
#   {'numberAnalysts': 31,
#    'period': '2020-12-31',
#    'revenueAvg': 30181619607,
#    'revenueHigh': 33285048000,
#    'revenueLow': 25425640000},
#   {'numberAnalysts': 35,
#    'period': '2019-12-31',
#    'revenueAvg': 24851521707,
#    'revenueHigh': 26616900000,
#    'revenueLow': 23128583000},
#   {'numberAnalysts': 32,
#    'period': '2018-12-31',
# ...

# %%
pd.DataFrame(finnhub_client.company_basic_financials('TSLA', 'margin'))
# Out:
#                                     metric metricType symbol
# freeOperatingCashFlow/revenue5Y  -10.34128     margin   TSLA
# freeOperatingCashFlow/revenueTTM   3.10954     margin   TSLA
# grossMargin5Y                     18.67445     margin   TSLA
# grossMarginAnnual                 16.55546     margin   TSLA
# grossMarginTTM                    19.77206     margin   TSLA
# netProfitMargin5Y                 -7.28780     margin   TSLA
# netProfitMarginAnnual             -3.15323     margin   TSLA
# netProfitMarginTTM                 1.86323     margin   TSLA
# operatingMargin5Y                 -5.04491     margin   TSLA
# operatingMarginAnnual             -0.28074     margin   TSLA
# operatingMarginTTM                 4.78450     margin   TSLA
# pretaxMargin5Y                    -7.99014     margin   TSLA
# pretaxMarginAnnual                -2.70567     margin   TSLA
# pretaxMarginTTM                    2.21721     margin   TSLA

# %%
pd.DataFrame(finnhub_client.financials_reported(symbol='TSLA', freq='annual'))
# Out:
#        cik                                               data symbol
# 0  1318605  {'accessNumber': '0001564590-20-004475', 'symb...   TSLA
# 1  1318605  {'accessNumber': '0001564590-19-003165', 'symb...   TSLA
# 2  1318605  {'accessNumber': '0001564590-18-002956', 'symb...   TSLA
# 3  1318605  {'accessNumber': '0001564590-17-003118', 'symb...   TSLA
# 4  1318605  {'accessNumber': '0001564590-16-013195', 'symb...   TSLA
# 5  1318605  {'accessNumber': '0001564590-15-001031', 'symb...   TSLA
# 6  1318605  {'accessNumber': '0001193125-14-069681', 'symb...   TSLA
# 7  1318605  {'accessNumber': '0001193125-13-096241', 'symb...   TSLA
# 8  1318605  {'accessNumber': '0001193125-12-081990', 'symb...   TSLA

# %%
{'2024': [{'numberAnalysts': 21,
   'period': '2024-12-31',
   'revenueAvg': 96416624918,
   'revenueHigh': 100273289915,
   'revenueLow': 93524126171},
  {'numberAnalysts': 21,
   'period': '2023-12-31',
   'revenueAvg': 71828831980,
   'revenueHigh': 74701985259,
   'revenueLow': 69673967020},
  {'numberAnalysts': 25,
   'period': '2022-12-31',
   'revenueAvg': 54313992266,
   'revenueHigh': 70521882000,
   'revenueLow': 35304120000},
  {'numberAnalysts': 31,
   'period': '2021-12-31',
   'revenueAvg': 41937343852,
   'revenueHigh': 50703180000,
   'revenueLow': 31743250000},
