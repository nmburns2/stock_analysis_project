# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
amazon_df = pd.read_csv("data/AMZN.csv")
amazon_df.head()
# Out:
#       Date      Open      High       Low     Close  Adj Close
# 0  5/15/97  2.437500  2.500000  1.927083  1.958333   1.958333
# 1  5/16/97  1.968750  1.979167  1.708333  1.729167   1.729167
# 2  5/19/97  1.760417  1.770833  1.625000  1.708333   1.708333
# 3  5/20/97  1.729167  1.750000  1.635417  1.635417   1.635417
# 4  5/21/97  1.635417  1.645833  1.375000  1.427083   1.427083

# %%
amazon_df[['Date', 'High']].set_index('Date').plot()
plt.ylabel('Price')
plt.title('Amazon Highest Prices over the Years')
plt.savefig('Highest Prices over the Years from Amazon.png')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
